# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from __future__ import print_function
import sys, os
import getdist.plots as gplot
import os

g=gplot.getSubplotPlotter(subplot_size=5, chain_dir=r'/home/coco/Desktop/work/Planck2018/base_r/plikHM_TTTEEE_lowl_lowE_lensing')
g.settings.legend_frame = False
g.settings.figure_legend_frame = False
g.settings.no_extra_legend_space = True
roots = ['base_r_plikHM_TTTEEE_lowl_lowE_lensing', 'base_r_plikHM_TTTEEE_lowl_lowE_lensing_post_BAO']
pairs = [('ns', 'r'), ('ns', 'r02'), ('ns', 'rBB'), ('ns', 'r10')]
g.figure_legend_frame = False
g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_legend(['Planck TTTEEE + LowE + Lensing','Planck TTTEEE + LowE + Lensing + BAO'], colored_text=True, fontsize=15, legend_loc='upper right', figure=True)
