# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from __future__ import print_function
import sys, os
import getdist.plots as gplot

g=gplot.getSubplotPlotter(subplot_size=5, chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_r/plikHM_TTTEEE_lowl_lowE_lensing')
g.settings.legend_frame = False
g.settings.figure_legend_frame = False
g.settings.no_extra_legend_space = True
roots = ['base_r_plikHM_TTTEEE_lowl_lowE_lensing', 'base_r_plikHM_TTTEEE_lowl_lowE_lensing_post_BAO']
pairs = [('ns02', 'r'), ('ns02', 'r02'), ('ns02', 'rBB'), ('ns02', 'r10')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_legend(['Planck TTTEEE + LowE + Lensing','Planck TTTEEE + LowE + Lensing + BAO'], colored_text=True, fontsize=15, legend_loc='upper right', figure=False)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_r/plikHM_TTTEEE_lowl_lowE_lensing')
g.settings.legend_frame = False
g.settings.legend_loc = 'best'
g.settings.figure_legend_frame = False

roots = ['base_r_plikHM_TTTEEE_lowl_lowE_lensing','base_r_plikHM_TTTEEE_lowl_lowE_lensing_post_BAO']
pairs = [('ns02','r')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], label=['N = 60'], ls='None', zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], label=['N = 50'], ls='None', zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TTTEEE + Lensing','Planck TTTEEE + Lensing + BAO'], colored_text=True, fontsize=13, legend_loc='upper left', figure=False)
leg2 = g.subplots[0,0].legend(['N = 60', 'N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig1.pdf',adir='coupling/150205193/figures/')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_nrun_r/plikHM_TTTEEE_lowl_lowE_lensing')

g.settings.legend_frame = False
g.settings.legend_loc = 'best'

roots = ['base_nrun_r_plikHM_TTTEEE_lowl_lowE_lensing','base_nrun_r_plikHM_TTTEEE_lowl_lowE_lensing_post_BAO']
pairs = [('ns02','r02')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], label=['N = 60'], zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], label=['N = 50'], zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TTTEEE + Lensing','Planck TTTEEE + Lensing + BAO'], colored_text=True, fontsize=13, legend_loc='upper left', figure=False)
leg2 = g.subplots[0,0].legend(['N = 60', 'N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig2.pdf',adir='coupling/150205193/figures/')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_nrun_r/plikHM_TT_lowl_lowE_lensing')

g.settings.legend_frame = False
g.settings.legend_loc = 'best'

roots = ['base_nrun_r_plikHM_TT_lowl_lowE_lensing','base_nrun_r_plikHM_TT_lowl_lowE_lensing_post_BAO']
pairs = [('ns','r')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TT + Lensing','Planck TT + Lensing + BAO'], colored_text=True, legend_loc='upper left', fontsize=13, figure=False)
leg2 = g.subplots[0,0].legend(['N = 60','N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig3.pdf',adir='coupling/150205193/figures/')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_r/plikHM_TT_lowl_lowE_lensing')

g.settings.legend_frame = False
g.settings.legend_loc = 'best'

roots = ['base_r_plikHM_TT_lowl_lowE_lensing','base_r_plikHM_TT_lowl_lowE_lensing_post_BAO']
pairs = [('ns','r')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], label=['N = 60'], zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], label=['N = 50'], zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TT + Lensing','Planck TT + Lensing + BAO'], colored_text=True, fontsize=13, legend_loc='upper left', figure=False)
leg2 = g.subplots[0,0].legend(['N = 60', 'N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig4.pdf',adir='coupling/150205193/figures/')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_nrun_r/plikHM_TT_lowl_lowE')

g.settings.legend_frame = False
g.settings.legend_loc = 'best'

roots = ['base_nrun_r_plikHM_TT_lowl_lowE','base_nrun_r_plikHM_TT_lowl_lowE_post_BAO']
pairs = [('ns','r02')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], label=['N = 60'], zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], label=['N = 50'], zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TT','Planck TT + BAO'], colored_text=True, fontsize=13, legend_loc='upper left', figure=False)
leg2 = g.subplots[0,0].legend(['N = 60', 'N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig5.pdf',adir='coupling/150205193/figures/')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from __future__ import print_function
import sys, os
import getdist.plots as gplot

g = gplot.getSinglePlotter(chain_dir=r'/Volumes/Newton/planck/COM_CosmoParams_fullGrid_R3.00/base_nrun_r/plikHM_TT_lowl_lowE_lensing')

g.settings.legend_frame = False
g.settings.legend_loc = 'best'

roots = ['base_nrun_r_plikHM_TT_lowl_lowE_lensing','base_nrun_r_plikHM_TT_lowl_lowE_lensing_post_BAO']
pairs = [('ns','r02')]

g.plots_2d(roots, param_pairs=pairs, legend_labels=[], filled=True, shaded=False)
g.add_line([0.96694214876], [0.132231404959], label=['N = 60'], zorder=3, color='red', marker='o', markeredgewidth=2)
g.add_line([0.960396039604], [0.158415841584], label=['N = 50'], zorder=3, color='red', marker='o', markeredgewidth=7)
leg1 = g.add_legend(['Planck TTTEEE + Lensing','Planck TTTEEE + Lensing + BAO'], colored_text=True, fontsize=13, legend_loc='upper left', figure=False)
leg2 = g.subplots[0,0].legend(['N = 60', 'N = 50'], loc='upper right', frameon=False)
g.subplots[0,0].add_artist(leg1)
g.export('fig2.pdf',adir='coupling/150205193/figures/')
